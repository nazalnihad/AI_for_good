# %% [markdown]
# <a href="https://colab.research.google.com/github/nazalnihad/AI_for_good/blob/main/chunking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install "unstructured[all-docs]"

# %%
# !pip install unstructured
# !pip install "unstructured[pdf]"

# %%
from unstructured.partition.auto import partition
elements = partition(filename="/content/farm.pdf")

# %%
elements

# %%
for element in elements :
  print("==================")
  print(element)
  print("==================")
# Out:
# ==================
# Satyamev Jayate Farmer Cup: Marking System
# ==================
# ==================
# The lone farmer survives from one crisis to the next. From poor quality seeds to drought to a collapse of market prices, there is danger lurking at every step. A farmer cannot solve these problems alone. However, Farmer Producer Organisations owned by large numbers of farmers can use their collective strength to solve these problems. Amul and Sahyadri Agro are a few examples of Farmer Producer Organisations who have proved that collectivisation of farming can create the eco-system necessary for farming to thrive. These models can and must be replicated on a massive scale. However, these models only work if they have a strong foundation and are built from the ground up. The gat is the first step which must be built and strengthened. This competition aims to motivate and train farmers in the process of collectivisation. It aims to start farmers on the journey from debt to prosperity.
# ==================
# ==================
# KEY GOALS FOR STAGE 1
# ==================
# ==================
# 1. Create demos/models that will demonstrate that only through collectivisation can farmers solve their problems.
# ==================
# ==================
# 2. To rekindle enthusiasm and joy in farming through collectivism.
# ==================
# ==================
# 3. To identify good gats. These gats will serve as the stepping stone to larger gats/FPCs which will be able to solve increasingly larger and more complex problems faced by farmers.
# ==================
# ==================
# 4. To identify good leadership within the gats, in other words to find and nurture entrepreneurs who have the right motivation, vision and capability to create larger gats/FPCs which can solve increasingly larger problems faced by farmers.
# ==================
# ==================
# 5. To create financial literacy among farmers by making them aware of the detailed costs and revenue of their crop.
# ==================
# ==================
# RULES FOR THE COMPETITION
# ==================
# ==================
# 1. Cropwise Gat
# ==================
# ==================
# The gat must be of farmers cultivating a single crop. Farmers in a gat may cultivate more than one crop, however all farmers in the gat must cultivate the crops in the same ratio.
# ==================
# ==================
# Eg. A gat which cultivates soybean as the main crop with 4 lines and tur as the intercrop with 2 lines should fill the entry form for the competition in the soybean category provided all farmers in the gat cultivate soybean and tur in the same ratio of 4:2.
# ==================
# ==================
# A single farmer can be a member of more than one gat. A farmer can be a member of only one gat for any particular crop. However, each of these gats must be formed for a single crop.
# ==================
# ==================
# 2. Multi-village Gats
# ==================
# ==================
# The farmers in a single gat may be from more than one village which are proximate to each other.
# ==================
# ==================
# 3. Minimum Area
# ==================
# ==================
# The minimum land under gat cultivation for that particular crop should not be less than 25 acres. However, all 25 or more acres should be assigned for selling crops/produce in the market. Crops grown for personal consumption should not be part of these 25 or more acres. Having a minimum of 25 acres under cultivation enables a gat to utilise economies of scale in purchase of inputs and sale of the crop. A single farmer in the gat should not have more than half the land under cultivation in the gat.
# ==================
# ==================
# 4. Minimum Number of Farmers There must be a minimum number of at least 20 farming families in the gat. Every family which is a single economic group will be considered as a single farming family even if there are more than one khatedaars in the family.
# ==================
# ==================
# 5. Process of Participation in the Competition by the Gat
# ==================
# ==================
# The process of participation in the competition is in two stages.
# ==================
# ==================
# Stage 1: Any group of farmers that wants to participate in the competition must click on the link provided by Paani Foundation and fill the Entry form in which they specify the following: Name of the gat, Crop to be cultivated, Names of 3 Convenors (Nimantraks) of the gat, with whatsapp no. and size of land on which the selected crop is being cultivated.
# ==================
# ==================
# Stage 2: Each of the convenors will be sent a link that will enable the names of the remaining members of the gats to be entered along with their cell number and area under cultivation. These details must be entered on or before 15th May 2022. It is only after Stage 2 is completed in accordance with the rules that the gat will be admitted into the competition.
# ==================
# ==================
# The members of a gat may be men or women. Existing Women Self Help Groups or Atma Groups are eligible to participate. However, government registration is not compulsory when enrolling for the competition.
# ==================
# ==================
# 6. Talukas and villages in the Competition
# ==================
# ==================
# This competition is a part of the Satyamev Jayate Samruddha Gaav Spardha. Hence, the members of the gat must be from one of the 39 talukas and participating villages in the Samruddha Gaav Spardha. However, a maximum of 25% of the members of a gat can be from villages that are not participating in the Samruddha Gaav Spardha but are adjoining such villages provided that all the Nimantraks (Convenors) of the gat are from Samruddha Gaav Villages. A taluka will be eligible to participate in the competition subject to a minimum of 10 gats from the taluka participating in the competition.
# ==================
# ==================
# 7. Crops in the Competition
# ==================
# ==================
# For the purposes of the competition, the following major kharif crops are included:
# ==================
# ==================
# 01. Bajri 02. Maize 03. Paddy 04. Jwari 05. Ragi 06. Tur 07. Moong 08. Udid 09. Groundnut 10. Soyabean 11. Cotton 12. Coriander seeds 13. Ajwain 14. Beans 15. Cabbage 16. Cauliflower 17. Capscicum
# ==================
# ==================
# 18. Brinjal 19. Okra 20. Onion 21. Ivy Gourd 22. Potato 23. Sweet Potato 24. Pumpkin 25. Tomato 26. Bitter Gourd 27. Bottle Gourd 28. Pointed Gourd 29. Ridged Gourd 30. Spongy Gourd 31. Peas 32. Chilli 33. Coriander 34. Fenugreek 35. Spinach 36. Cluster Beans
# ==================
# ==================
# The Department of Planning Government of Maharashtra through its Directorate of Statistics and Economics has published the results of a survey of the cost and revenue data of various crops in Maharashtra. These are the crops included in this competition.
# ==================
# ==================
# 8. Kharif Season-End Date
# ==================
# ==================
# For the purposes of this competition, harvesting must be completed and data entered on or before 31st January 2023. In the event of multiple flush crops like cotton, only the harvest obtained on or before 31st January 2023 will be considered valid.
# ==================
# ==================
# Some crops have a short cropping season, and more than one crop can be cultivated in the kharif season eg. Moong plus cauliflower. A single gat can enter the data for more than one crop provided the entire gat is cultivating moong AND cauliflower as its major crop AND FURTHER PROVIDED that the harvest and all data entry has been completed on or before 31st January 2023.
# ==================
# ==================
# All the sections in Mulyankan Paddhat will be independently applicable to both the crops.
# ==================
# ==================
# 9. Prizes
# ==================
# ==================
# Prizes will be given to the gat. There will be 3 prizes at the state level. The first prize will be Rs. 25 lakhs, the second Rs. 15 lakh and the third prize will be Rs. 10 lakhs.
# ==================
# ==================
# There will also be a single prize of Rs 1 lakh at the taluka level. A gat winning a prize at the state level will not be eligible for a taluka level prize. A taluka level prize will be given subject to the gat getting at least 70% marks. Eg. If not a single gat in a taluka gets 70% marks in the competition, then no taluka level prize will be given for that taluka.
# ==================
# ==================
# No employee of the Paani Foundation or his/her family member will be eligible to win a prize.
# ==================
# ==================
# 10. Last Date for Participation
# ==================
# ==================
# In order to participate an eligible gat must complete the first stage of registration on or before 15th May 2022 and the second stage of registration on or before 31st May 2022.
# ==================
# ==================
# The competition will start on 15th May 2022.
# ==================
# ==================
# 11. Judging
# ==================
# ==================
# The data for the competition is to be filled by the farmers/gats on the Paani Foundation App. The data filled in by all gats/farmers who stand a chance of winning prizes will be verified by one or more teams appointed by Paani Foundation for that purpose. For this purpose, books of account and other documents will be examined, and individual members of the gat will be interviewed to verify information given by the gat. In particular the sales receipts will be examined and compared with prevailing mandi prices at the time of sale. Gats which have deliberately falsified entries will be disqualified from the competition.
# ==================
# ==================
# Gats are expected to maintain photos/videos of the various activities that are part of this competition and also post these on the whatsapp group of the gat. These will be examined by the judges.
# ==================
# ==================
# The performance of the gat could be affected by climatic and natural calamities like drought, floods etc. Unfortunately, these cannot be captured by the rules of the competition and the results could be affected.
# ==================
# ==================
# 12. The decision taken by the judges will be final.
# ==================
# ==================
# MARKING SYSTEM AT A GLANCE
# ==================
# ==================
# Knowledge: 30 Marks
# ==================
# ==================
# Production Process: 30 Marks
# ==================
# ==================
# Sustainable Practices: 30 Marks
# ==================
# ==================
# Sale: 30 Marks
# ==================
# ==================
# Institution Building: 80 Marks
# ==================
# ==================
# Total = 200 Marks
# ==================
# ==================
# MARKING SYSTEM DETAILS
# ==================
# ==================
# I. KNOWLEDGE: 30 MARKS
# ==================
# ==================
# 1. Designing a System of Good Practices: 5 Marks
# ==================
# ==================
# Each gat must design a system of good practices - SOPs (Standard Operating Practices) to be followed by each farmer in the gat -- from soil preparation to harvesting and storage. 10 or more SOPs must be defined for the selected crop. These are practices that all members of the gat agree upon. Preparing this list of SOPs/good practices is necessary so that one can be prospective not reactive, so that one can plan to prevent problems rather than react after problems have occurred. It is a way towards making agriculture knowledge based. Here are a few examples of the subjects covered by the good practices:
# ==================
# ==================
# Pre-sowing field preparation, seed treatment, sowing method, plant spacing, nutrient management, weed management, water management, pest management, harvesting, storage of the crop.
# ==================
# ==================
# This creation of a list of SOPs/good practices for that particular crop must be done in consultation with experts - whether from the agricultural universities or progressive
# ==================
# ==================
# farmers or other experts. Paani Foundation will make all efforts to connect the gat with an expert/s. However, the gat will be at liberty to select their expert and the responsibility of creating the SOPs/good practices will be entirely that of the gat.
# ==================
# ==================
# The system of SOPs/good practices must be entered by the gat on the Paani Foundation App before cultivation commences. The gat will get 5 Marks for entering the SOPs/good practices on the Paani Foundation App.
# ==================
# ==================
# 2. Actual Implementation of Good Practices: 20 Marks
# ==================
# ==================
# The gat must enter on the Paani Foundation App which of the SOPs/good practices have been followed by each member of the gat.
# ==================
# ==================
# The gat will get marks in proportion to the percentage of SOPs followed by all the members of the gat. So eg. if the gat has planned to implement 10 SOPs and 100% of the members of the gat implement all 10 SOPs, then the gat will get full 20 Marks. If however only 8 of the SOPs have been implemented by all the members of the gat then the gat will get 16 Marks.
# ==================
# ==================
# If a gat has selected more than 10 SOPs but all its members have implemented at least 10 SOPs, then it will be entitled to get 20 marks.
# ==================
# ==================
# The photos and videos of the SOPs followed by the members of the Gat must be posted on the Gat's WhatsApp group. These photos and videos will be checked during the judging process.
# ==================
# ==================
# 3. Peer to peer learning and learning from Progressive Farmers: 5 Marks
# ==================
# ==================
# Improvement of productivity, improvement in quality and lowering of costs in agriculture is only possible through continuous improvements in the knowledge system of farmers. Peer to peer learning and exposure visits to progressive farmers is an important method of making the best knowledge available. 5 Marks will be given to gats that make the following efforts:
# ==================
# ==================
# i. Exposure visit to successful farmers cultivating this crop. Gats must enter the name of the progressive farmer and the date on which her/his field was visited. 1 mark will be given to a gat that does at least one such exposure visit to a successful farmer.
# ==================
# ==================
# The photos and videos of such an exposure visit done by the Gat must be posted on the Gat's WhatsApp group. These photos and videos will be checked during the judging process.
# ==================
# ==================
# ii. Shivarferi whereby gat members visit each other’s fields and closely observe each other’s fields. Gats must enter the dates on which the shivarferi is done. 1 marks will be given to a gat for every such shivarferi for a total of 3 marks.
# ==================
# ==================
# The photos and videos of such a shivarferi/s done by the Gat must be posted on the Gat's WhatsApp group. These photos and videos will be checked during the judging process.
# ==================
# ==================
# iii. A gat must have its own whatsapp group where they share information and photographs pertaining to their crop. They can share problems and solutions as part of peer-to-peer learning. This whatsapp group should not be used for forwards pertaining to entertainment, politics or other topics not pertaining to agriculture. 1 Mark will be given to a gat that maintains such a whatsapp group.
# ==================
# ==================
# II. PRODUCTION PROCESS: 30 MARKS
# ==================
# ==================
# 1. Joint Purchase of Inputs:10 marks
# ==================
# ==================
# Collective purchase of farming inputs helps drive down costs through economies of scale. Hence the purchase of farming inputs through the gat will be given marks in accordance with the table below.
# ==================
# ==================
# Percentage of farming inputs purchased through the gat
# ==================
# ==================
# Marks
# ==================
# ==================
# 75% +
# ==================
# ==================
# 10
# ==================
# ==================
# 60% + to 75%
# ==================
# ==================
# 8
# ==================
# ==================
# 50% + to 60%
# ==================
# ==================
# 6
# ==================
# ==================
# 40% + to 50%
# ==================
# ==================
# 4
# ==================
# ==================
# 30% ते 40%
# ==================
# ==================
# 2
# ==================
# ==================
# Less than 30
# ==================
# ==================
# 0
# ==================
# ==================
# The receipt of the vendor/s will certify that the purchase has been made on behalf of the gat. The information pertaining to the joint purchase by the gat as also the individual purchase by the member of the gat along with the supporting bills, receipts etc must be uploaded on the Paani Foundation App.
# ==================
# ==================
# 2. Joint Labour - Irjik: 20 Marks
# ==================
# ==================
# Shared labour or irjik is part of the rich tradition of our villages whereby farmers work on each other’s fields for key agricultural operations like sowing, weeding etc. Irjik creates trust and a deep bond between farmers. By bringing people together it also creates joy in the process of farming. The gat must enter for which agricultural process irjik has been done eg. Sowing, weeding etc. 4 marks will be given per process for which irjik is done. So if farmers in a gat do irjik for 5 agricultural processes then they will get full 20 marks. If they do irjik for only one process, then they will get only 4 marks.
# ==================
# ==================
# For such process, the irjik must have been done on the field of every farmer. It is not necessary for a member of the gat to participate in every single irjik, but every farmer in the gat must participate in at least some irjik. For any process which has been selected for Irjik, if even one farmer has not participated in irjik for that process or even one farmer has not had the benefit of a single irjik in his/her field for that process, the gat will get zero marks for that process. Work done for a fee will not be considered as shared labour.
# ==================
# ==================
# The photos and videos of all activities / work done by the Gat in this regard must be posted on the Gat's WhatsApp group. These photos and videos will be checked during the judging process.
# ==================
# ==================
# III. SUSTAINABLE PRACTICES: 30
# ==================
# ==================
# 1. Residue Free Farming: 20 marks
# ==================
# ==================
# Reducing the use of chemicals particularly pesticides, weedicides and fungicides is important for the consumer, farmer and agricultural labour and for our planet. Adoption of non-pesticide management is an important step in that direction. There are multiple practices that can help farmers avoid pesticides and weedicides ranging from multiple crops on a single field to the use of sticky traps and pheromone traps to the use of jeevamrut and various bio-pesticides.
# ==================
# ==================
# How good a particular method is can only be verified through the testing of agricultural produce for chemical residues. The government of India specifies the Maximum
# ==================
# ==================
# Residue Limit for each crop. The aim of the gat should be to ensure that every single farmer in the gat creates produce within the limits specified by the government. For this purpose the gat must organise a test at a government approved laboratory of a random sample of the produce of the gat and upload the results on the App.
# ==================
# ==================
# The method of selecting a random sample will be specified by a third-party agency approved by Paani Foundation.
# ==================
# ==================
# If this produce is within the MRL for that particular crop, the gat will get full 20 Marks. If the random sample tests more than the MRL then the gat will get zero marks under this section.
# ==================
# ==================
# Although the testing of produce will put a burden of cost on the gat, this certification of the produce as being within minimum residue limits will also help the gat achieve a premium price for their produce.
# ==================
# ==================
# 2. Percentage of Land Under Drip / Water-Saving Technologies: 5 marks
# ==================
# ==================
# The use of drip, sprinkler and mulching enables substantial water saving. The gat must specify if the member farmers are using one or more of any these methods and for what extent of the land. The gat will be awarded marks as per the extent of land under water saving technologies in accordance with the table below.
# ==================
# ==================
# Percentage of irrigated land under water saving technologies
# ==================
# ==================
# Marks
# ==================
# ==================
# 75% +
# ==================
# ==================
# 5
# ==================
# ==================
# 70% + ते 75%
# ==================
# ==================
# 4
# ==================
# ==================
# 65% + ते 70%
# ==================
# ==================
# 3
# ==================
# ==================
# 60% + ते 65%
# ==================
# ==================
# 2
# ==================
# ==================
# 55% ते 60%
# ==================
# ==================
# 1
# ==================
# ==================
# Less than 55%
# ==================
# ==================
# 0
# ==================
# ==================
# Any extent of land that is entirely rain fed and not under irrigation is excluded for the purposes of this section.
# ==================
# ==================
# Members of the gat must take photos/videos of the work done under this Section and post these on the gat’s whatsapp Group. These will be examined during the judging process.
# ==================
# ==================
# 3. Matchbox Free Village: 5 Marks
# ==================
# ==================
# 5 Marks will be given to a gat that composts all of its crop residue by one method or another and does not burn any crop residue. Crop residues may be ploughed into the soil or be turned into slurry through bio-methanation or through the use of bio dynamix, or waste decomposer or NADEP. The method through which the crop residue is composted may be selected by an individual farmer so long as no crop residue is burnt. To get full marks in this section, every member of the gat must implement one of the methods mentioned above. The gat must enter in the App what is done to the crop remains for every member of the gat. Every member of the gat should take photos/videos regarding the same and post these on the gat’s whatsapp group. These will be examined during the judging process.
# ==================
# ==================
# IV. SALE: 30 Marks
# ==================
# ==================
# 1. Collective Efforts for Sale: 10 Marks
# ==================
# ==================
# One of the important purposes for which a gat is established is to achieve better price realisation for the crop using its collective strength. For this purpose, it is important that the gat gets together to sell its produce. Every farmer must as part of the spardha enter data pertaining to his/her revenue on the Paani Foundation App. The sum total of the revenue of every member of the gat amounts to the total revenue of the gat. The gat must specify how much of the total revenue of the gat was obtained by collective sale as a gat along with supporting bills and documents. Marks will be given to the gat depending on the percentage of the total revenue of the gat obtained by collective sale as a gat. These marks will be given in accordance with the table below.
# ==================
# ==================
# Percentage of the total revenue of the gat that is obtained by collective sale as a gat
# ==================
# ==================
# Marks
# ==================
# ==================
# 75% +
# ==================
# ==================
# 10
# ==================
# ==================
# 60% + to 75%
# ==================
# ==================
# 8
# ==================
# ==================
# 50% + to 60%
# ==================
# ==================
# 6
# ==================
# ==================
# 40% + to 50%
# ==================
# ==================
# 4
# ==================
# ==================
# 30% to 40%
# ==================
# ==================
# 2
# ==================
# ==================
# Less than 30%
# ==================
# ==================
# 0
# ==================
# ==================
# If farmers have stored their produce for better price realisation later, they should produce the relevant documents establishing this. For any non-perishable produce that has been safely stored and not sold the sale price will be assumed to be the prevailing mandi price on 31st January 2023. Similarly, if the Gat plans to collectively sell the produce in future, it should specify that in the app.
# ==================
# ==================
# In the case of maize that is converted into silage for self use by the dairy farmer the sale price of the silage is assumed to be Rs. 5/- kg. This assumption is being made since there will be no bill for sale to one’s own self.
# ==================
# ==================
# 2. Value Addition. 15 Marks
# ==================
# ==================
# Every crop carries with it the possibility of value addition in one form or another. Eg. millets can be turned into flour and various products made out of millets. Maize can be processed into silage. In all crops, cleaning and grading offers the possibility of value addition. Cleaning and grading of produce and all forms of value addition help the farmer get better prices in the market. It also helps establish the reputation of the gat. 15 Marks will be given to the gat that does value addition to its crop. If the gat does value addition to only a part of the produce of the farmers it will get marks in proportion to the extent to which such value addition has been done.
# ==================
# ==================
# E.g. If the total production of the Gat is 100 quintals of which value addition has been done for 50 quintals, then the Gat will get 7.5 marks in this category.
# ==================
# ==================
# The photos and videos of all activities / work done by the Gat in this regard must be posted on the Gat's WhatsApp group. These photos and videos will be checked during the judging process.
# ==================
# ==================
# 3. Arrangements for Storage: 5 marks
# ==================
# ==================
# Often prices crash during the harvest period but go up once the harvest period is over. Proper arrangements for storage are critical to being able to achieve a proper price for the product. Storage with warehouse receipts can also enable farmers to get a cash flow and hold onto their produce till they get a proper price. A lot of storage
# ==================
# ==================
# arrangements are available on rent but an individual farmer is not able to spend the money on transport or on rent. Making arrangements for storage is therefore a critical part of the functioning of a gat. For this purpose, a gat must show documentation that establishes that the gat has gathered information about available storage and made arrangements for such storage which includes information about the cost of such storage, when it would be made available and the volume of such availability. The decision whether to use such storage would be that of the individual farmer. 5 marks will be given to a gat which makes arrangements for storage. Please note these marks will be given whether or not farmers actually use these storage arrangements.
# ==================
# ==================
# Since Onion, Tomato, Cauliflower, Cabbage and other vegetables are highly perishable, storage arrangements are not viable for these crops and hence gats cultivating these crops will get full 5 marks under this Section.
# ==================
# ==================
# If storage is arranged at home, it should be recorded on the Paani Foundation app and the photos / videos should be posted on the WhatsApp group. These photos and videos will be checked during the judging process.
# ==================
# ==================
# V. GAT AS AN INSTITUTION: 80 Marks
# ==================
# ==================
# 1. Accounts of the Gat: 2.5 Marks
# ==================
# ==================
# A proper functioning gat is a business unit that must maintain proper books of account. The joint purchase of inputs, the contributions of Members for these inputs, the realisations from sale of the crop etc. must all be reflected in the books of account which must be entered on the Paani Foundation App.
# ==================
# ==================
# Hence, if proper books of account of the gat are not maintained, then it is not possible to calculate marks for several other sections in the competition eg. Joint Purchase of inputs: 10 Marks, Joint Efforts for Sale: 10 Marks, Value Addition: 15 Marks etc.
# ==================
# ==================
# If proper books of account of the gat are not maintained then there will be no option but to give zero marks for each of these sections.
# ==================
# ==================
# 2. Bank Account of the Gat : 2.5 Marks
# ==================
# ==================
# The gat must have a bank account for which it will get 2.5 Marks.
# ==================
# ==================
# 3. Farmers Books of Account Marks: 10 Marks
# ==================
# ==================
# Every individual farmer who is part of the gat is running a business and hence must keep books of account. 10 Marks will be given if every farmer in the gat maintains books of account via the Paani Foundation App. If only some members of the gat maintain books of account then the gat will get marks in proportion to the number of farmers maintaining books of account. Eg. In a gat with 20 members only 10 members maintain books of account, then the gat will get 5 marks.
# ==================
# ==================
# A farmer must make ALL the entries - from pre-sowing operations to transport for sale in the books of account to get marks under this Section.
# ==================
# ==================
# If all the members of the gat do not make all the entries on the Paani Foundation App as required by this Section, it is not possible to calculate marks for several other sections in the competition eg. Joint Purchase of inputs: 10 Marks, Joint Efforts for Sale: 10 Marks, Value Addition: 15 Marks, Profit of the gat : 40 Marks etc.
# ==================
# ==================
# If all the members of the gat do not make all the entries on the Paani Foundation App as required by this section, then there will be no option but to give zero marks for each of these sections.
# ==================
# ==================
# 4) Cost-Revenue for Previous Kharif Crop - 5 marks
# ==================
# ==================
# Writing the cost, revenue and yield for the previous kharif season will help farmers know whether or not this year’s farming is a step in the right direction. Hence marks will be given for entering this data for the previous kharif crop in accordance with the table below.
# ==================
# ==================
# Percentage of Members of the gat who enter cost, revenue yield data for the previous Kharif Crop
# ==================
# ==================
# Marks
# ==================
# ==================
# 50% +
# ==================
# ==================
# 5
# ==================
# ==================
# 40% + to 50%
# ==================
# ==================
# 4
# ==================
# ==================
# 30% + to 40%
# ==================
# ==================
# 3
# ==================
# ==================
# 20% + to 30%
# ==================
# ==================
# 2
# ==================
# ==================
# 10% to 20%
# ==================
# ==================
# 1
# ==================
# ==================
# Less than 10%
# ==================
# ==================
# 0
# ==================
# ==================
# Receipts / documents of Accounts are not expected in this regard.
# ==================
# ==================
# 5. Inter-gat Cooperation: 5 Marks
# ==================
# ==================
# The present gats are a stepping stone to large farmer producer organisations. The ultimate goal is an FPO - whether under the Companies Act or the Cooperative Societies Act which has the economies of scale necessary to solve all the problems of farmers. This requires farmers with at least 1,000 acres of land coming together. This cannot be achieved overnight. As a first step the gats competing in this competition should cooperate with other gats in the matter of purchase of inputs, sale of crop, marketing arrangements or any other matter that forms a part of this spardha.
# ==================
# ==================
# The competing gats must enter on the App the various activities for which they have entered into inter-gat cooperation along with supporting documents. For each such activity, 2.5 marks will be allotted. A total of 5 Marks will be allotted for inter-gat cooperation.
# ==================
# ==================
# 6. Contribution to Community Work: 5 Marks
# ==================
# ==================
# The gat is a part of the village and both benefits from and contributes to the overall well-being of the village. Gats can contribute to the village through shramdan for tree plantation, creation and maintenance of grasslands or any other activity that is a part of the Samruddha Gaav Spardha. The gat must enter on the App which of such activities the gat has participated in. Participation in 2 or more activities of the village will be given 5 marks. The Gat will receive 2.5 marks for each such activity. The group will get a maximum of 5 marks under this section.
# ==================
# ==================
# The photos and videos of all activities / work done by the Gat in this regard must be posted on the Gat's WhatsApp group. These photos and videos will be checked during the judging process.
# ==================
# ==================
# 7. Profitability of the Gat (40 marks)
# ==================
# ==================
# A gat is first and foremost an economic entity. Its success or failure and indeed its possibility of survival or growth will depend on its performance as an economic entity. The Profit and Loss statement of the gat will reveal its performance as an economic entity. Marks under this Section will be given under the headings of profit per acre and percentage of profits. The profits will be calculated in the following manner.
# ==================
# ==================
# The Planning Department, Government of Maharashtra through the Directorate of Statistics and Economics in June 2021 published its final report on the cost and revenue of various crops. Accordingly, a table giving the cost of production per acre of each crop is given in the appendix at the end of this document.
# ==================
# ==================
# This report is available via this link: https://mahades.maharashtra.gov.in/surveyReports.do?repCatId=CFA
# ==================
# ==================
# Using the costs given in the table above as a benchmark, the Paani Foundation App will calculate the cost of cultivation incurred by the gat in the following manner:
# ==================
# ==================
# Total cost of cultivation of the gat = Average cost of cultivation per the table above in Rs/acre x Number of acres cultivated by the gat
# ==================
# ==================
# In addition if the gat does value addition eg. converting maize into silage, then the costs pertaining to such conversion/value addition must be added. In further addition, the gat incurs costs pertaining to sale of the produce eg. cost of transport of handling, weighing and commission paid to traders. In case of safe storage of agricultural produce without sale till 31st January 2023, these expenses will be charged according to the rates available in the taluka market.
# ==================
# ==================
# Hence: Total cost of the gat = Total Cost of cultivation + Cost of Value addition (if any) + Costs incurred for sale.
# ==================
# ==================
# Now let’s see how the revenue of the gat is calculated.
# ==================
# ==================
# Total revenue of the gat = Sum of revenue from sale of the main crop by each farmer + Sum of revenue from sale of the intercrop by each farmer + Sum of revenue from sale of the by-product (eg. soybean straw) by each farmer + Sum of revenue from sale of the value added product (if any) by each farmer
# ==================
# ==================
# On this basis, the profit percentage and also profit/acre for each gat will be calculated.
# ==================
# ==================
# Profit of the gat = Total revenue of the gat – Total Cost of cultivation of the gat
# ==================
# ==================
# Profit percentage = Profit of the gat/Total Cost of the Gat x 100
# ==================
# ==================
# Profit/Acre = Profit of the Gat/Number of Acres under cultivation by the gat
# ==================
# ==================
# 20 marks are allocated for Profit/acre and 20 Marks forProfit Percentage.
# ==================
# ==================
# A. Profit per acre (Rs)
# ==================
# ==================
# Profit per acre (Rs)
# ==================
# ==================
# Marks
# ==================
# ==================
# 50,000 +
# ==================
# ==================
# 20
# ==================
# ==================
# 40,000 + to 50,000
# ==================
# ==================
# 16
# ==================
# ==================
# 30,000 + to 40,000
# ==================
# ==================
# 12
# ==================
# ==================
# 20,000+ to 30,000
# ==================
# ==================
# 8
# ==================
# ==================
# 10,000+ to 20,000
# ==================
# ==================
# 4
# ==================
# ==================
# 10,000 or less
# ==================
# ==================
# 0
# ==================
# ==================
# B. Profit percentage
# ==================
# ==================
# Profit percentage
# ==================
# ==================
# Marks
# ==================
# ==================
# 100%+
# ==================
# ==================
# 20
# ==================
# ==================
# 60%+ to 100%
# ==================
# ==================
# 15
# ==================
# ==================
# 40%+ to 60%
# ==================
# ==================
# 12
# ==================
# ==================
# 25%+ to 40%
# ==================
# ==================
# 8
# ==================
# ==================
# 10%+ to ते 25%
# ==================
# ==================
# 5
# ==================
# ==================
# 10% or less
# ==================
# ==================
# 0
# ==================
# ==================
# 8. Team Work, Leadership and Vision: 10 Marks
# ==================
# ==================
# A gat is a collection of human beings each with their own background, thoughts and points of view. One of the biggest challenges of the gat is good team work. How does a gat handle differences? What is its vision? What is the quality of leadership?. All these factors contribute greatly to the success or failure of the gat. All gats that stand a chance of winning a prize in the competition on the basis of all the other heads above will be judged on this criteria by Paani Foundation judges appointed for this purpose. 10 Marks have been allocated under this section.
# ==================
# ==================
# APPENDIX
# ==================
# ==================
# Name of Crop
# ==================
# ==================
# Production Cost/Acre in Rs Based on Govt. of Maharashtra Data
# ==================
# ==================
# Bajra
# ==================
# ==================
# 14317.39
# ==================
# ==================
# Maize
# ==================
# ==================
# 24302.07
# ==================
# ==================
# Kh. Paddy
# ==================
# ==================
# 23260.31
# ==================
# ==================
# Kh. Jowar
# ==================
# ==================
# 18182.56
# ==================
# ==================
# Ragi
# ==================
# ==================
# 11099.19
# ==================
# ==================
# Tur
# ==================
# ==================
# 22604.45
# ==================
# ==================
# Moong
# ==================
# ==================
# 17638.09
# ==================
# ==================
# Udid
# ==================
# ==================
# 15482.25
# ==================
# ==================
# Groundnut
# ==================
# ==================
# 32588.52
# ==================
# ==================
# Soybean
# ==================
# ==================
# 20718
# ==================
# ==================
# Cotton
# ==================
# ==================
# 26476.78
# ==================
# ==================
# Coriander Seed
# ==================
# ==================
# 17236.61
# ==================
# ==================
# Ajwain
# ==================
# ==================
# 27852
# ==================
# ==================
# Beans
# ==================
# ==================
# Cabbage
# ==================
# ==================
# Cauliflower
# ==================
# ==================
# Capsicum
# ==================
# ==================
# Brinjal
# ==================
# ==================
# Okra
# ==================
# ==================
# Kh. Onion
# ==================
# ==================
# Ivy gourd
# ==================
# ==================
# Potato
# ==================
# ==================
# Sweet Potato
# ==================
# ==================
# Pumpkin
# ==================
# ==================
# Tomato
# ==================
# ==================
# Bitter gourd
# ==================
# ==================
# Bottle gourd
# ==================
# ==================
# Pointed gourd
# ==================
# ==================
# Ridge gourd
# ==================
# ==================
# Sponge gourd
# ==================
# ==================
# Peas
# ==================
# ==================
# Green Chili
# ==================
# ==================
# Coriander
# ==================
# ==================
# Fenugreek
# ==================
# ==================
# Leafy Veg. (Spinach)
# ==================
# ==================
# Other Veg. (Cluster bean)
# ==================
# ==================
# LIST OF SOPs
# ==================
# ==================
# A. पूवमशागत १. उताराला आडवी नांगरणी करणे. २. उहात नांगरणी करणे. ३. पूण कु जलेले शेणखत मातीआड करणे.
# ==================
# ==================
# 70910.82
# ==================
# ==================
# 63710.1
# ==================
# ==================
# 60283.5
# ==================
# ==================
# 96244.67
# ==================
# ==================
# 75618.92
# ==================
# ==================
# 50973.45
# ==================
# ==================
# 38976.16
# ==================
# ==================
# 68330.43
# ==================
# ==================
# 89096.67
# ==================
# ==================
# 47356.71
# ==================
# ==================
# 75348.73
# ==================
# ==================
# 82125.69
# ==================
# ==================
# 74200.78
# ==================
# ==================
# 46990.83
# ==================
# ==================
# 45223.84
# ==================
# ==================
# 63444.83
# ==================
# ==================
# 75829.71
# ==================
# ==================
# 38214.89
# ==================
# ==================
# 70140.69
# ==================
# ==================
# 23554.54
# ==================
# ==================
# 25019.89
# ==================
# ==================
# 28404.51
# ==================
# ==================
# 29119.35
# ==================
# ==================
# B. बयाणे नवड १. उपलध वाणांचा अयास करणे. २. बयायाची उगवण मता तपासणी करणे. ३. बीजया करणे.
# ==================
# ==================
# C. पेरणी १. BBF पधतीने पेरणी करणे. २. सर वरंबा / गाद वायावर टोकन पधतीने पेरणी करणे. ३. पकांया दोन ओळी व रोपांमये योय अंतर ठे वणे.
# ==================
# ==================
# D. खतयवथापन १. माती परण करणे. २. माती परणानुसार खतांचा योय वापर करणे. ३. जीवामृत आण वाय खतांचा योय वापर करणे.
# ==================
# ==================
# E. तणनयंण १. सायकल कोळपे, हात कोळपे, खुरपणी वारे तणनयंण करणे.
# ==================
# ==================
# F. पाणी यवथापन १. ठबक संचन / तुषार संचन वारे पाणी देणे. २. आछादन करणे.
# ==================
# ==================
# G. कडयवथापन १. चकट सापळे वापरणे. २. काश सापळे वापरणे. ३. कामगंध सापळे वापरणे. ४. पीथांबे तयार करणे. ५. जैवक कटकनाशकांचा वापर करणे. ६. जैवक बुरशीनाशकांचा वापर करणे. ७. सापळा पके घेणे.
# ==================

# %%
from unstructured.chunking.title import chunk_by_title

# %%
chunks = chunk_by_title(elements)
for chunk in chunks:
   print("================")
   print(chunk)
   print("================")
# Out:
# ================
# Satyamev Jayate Farmer Cup: Marking System
# ================
# ================
# The lone farmer survives from one crisis to the next. From poor quality seeds to drought to a collapse of market prices, there is danger lurking at every step. A farmer cannot solve these problems alone. However, Farmer Producer Organisations owned by large numbers of farmers can use their collective strength to solve these problems. Amul and Sahyadri Agro are a few examples of Farmer Producer Organisations who have proved that collectivisation of farming can create the eco-system necessary for
# ================
# ================
# farming to thrive. These models can and must be replicated on a massive scale. However, these models only work if they have a strong foundation and are built from the ground up. The gat is the first step which must be built and strengthened. This competition aims to motivate and train farmers in the process of collectivisation. It aims to start farmers on the journey from debt to prosperity.
# ================
# ================
# KEY GOALS FOR STAGE 1
#
# 1. Create demos/models that will demonstrate that only through collectivisation can farmers solve their problems.
#
# 2. To rekindle enthusiasm and joy in farming through collectivism.
#
# 3. To identify good gats. These gats will serve as the stepping stone to larger gats/FPCs which will be able to solve increasingly larger and more complex problems faced by farmers.
# ================
# ================
# 4. To identify good leadership within the gats, in other words to find and nurture entrepreneurs who have the right motivation, vision and capability to create larger gats/FPCs which can solve increasingly larger problems faced by farmers.
#
# 5. To create financial literacy among farmers by making them aware of the detailed costs and revenue of their crop.
# ================
# ================
# RULES FOR THE COMPETITION
#
# 1. Cropwise Gat
#
# The gat must be of farmers cultivating a single crop. Farmers in a gat may cultivate more than one crop, however all farmers in the gat must cultivate the crops in the same ratio.
#
# Eg. A gat which cultivates soybean as the main crop with 4 lines and tur as the intercrop with 2 lines should fill the entry form for the competition in the soybean category provided all farmers in the gat cultivate soybean and tur in the same ratio of 4:2.
# ================
# ================
# A single farmer can be a member of more than one gat. A farmer can be a member of only one gat for any particular crop. However, each of these gats must be formed for a single crop.
#
# 2. Multi-village Gats
#
# The farmers in a single gat may be from more than one village which are proximate to each other.
#
# 3. Minimum Area
# ================
# ================
# The minimum land under gat cultivation for that particular crop should not be less than 25 acres. However, all 25 or more acres should be assigned for selling crops/produce in the market. Crops grown for personal consumption should not be part of these 25 or more acres. Having a minimum of 25 acres under cultivation enables a gat to utilise economies of scale in purchase of inputs and sale of the crop. A single farmer in the gat should not have more than half the land under cultivation in the ga
# ================
# ================
# t.
# ================
# ================
# 4. Minimum Number of Farmers There must be a minimum number of at least 20 farming families in the gat. Every family which is a single economic group will be considered as a single farming family even if there are more than one khatedaars in the family.
#
# 5. Process of Participation in the Competition by the Gat
#
# The process of participation in the competition is in two stages.
# ================
# ================
# Stage 1: Any group of farmers that wants to participate in the competition must click on the link provided by Paani Foundation and fill the Entry form in which they specify the following: Name of the gat, Crop to be cultivated, Names of 3 Convenors (Nimantraks) of the gat, with whatsapp no. and size of land on which the selected crop is being cultivated.
# ================
# ================
# Stage 2: Each of the convenors will be sent a link that will enable the names of the remaining members of the gats to be entered along with their cell number and area under cultivation. These details must be entered on or before 15th May 2022. It is only after Stage 2 is completed in accordance with the rules that the gat will be admitted into the competition.
# ================
# ================
# The members of a gat may be men or women. Existing Women Self Help Groups or Atma Groups are eligible to participate. However, government registration is not compulsory when enrolling for the competition.
#
# 6. Talukas and villages in the Competition
# ================
# ================
# This competition is a part of the Satyamev Jayate Samruddha Gaav Spardha. Hence, the members of the gat must be from one of the 39 talukas and participating villages in the Samruddha Gaav Spardha. However, a maximum of 25% of the members of a gat can be from villages that are not participating in the Samruddha Gaav Spardha but are adjoining such villages provided that all the Nimantraks (Convenors) of the gat are from Samruddha Gaav Villages. A taluka will be eligible to participate in the compe
# ================
# ================
# tition subject to a minimum of 10 gats from the taluka participating in the competition.
# ================
# ================
# 7. Crops in the Competition
#
# For the purposes of the competition, the following major kharif crops are included:
#
# 01. Bajri 02. Maize 03. Paddy 04. Jwari 05. Ragi 06. Tur 07. Moong 08. Udid 09. Groundnut 10. Soyabean 11. Cotton 12. Coriander seeds 13. Ajwain 14. Beans 15. Cabbage 16. Cauliflower 17. Capscicum
# ================
# ================
# 18. Brinjal 19. Okra 20. Onion 21. Ivy Gourd 22. Potato 23. Sweet Potato 24. Pumpkin 25. Tomato 26. Bitter Gourd 27. Bottle Gourd 28. Pointed Gourd 29. Ridged Gourd 30. Spongy Gourd 31. Peas 32. Chilli 33. Coriander 34. Fenugreek 35. Spinach 36. Cluster Beans
# ================
# ================
# The Department of Planning Government of Maharashtra through its Directorate of Statistics and Economics has published the results of a survey of the cost and revenue data of various crops in Maharashtra. These are the crops included in this competition.
#
# 8. Kharif Season-End Date
# ================
# ================
# For the purposes of this competition, harvesting must be completed and data entered on or before 31st January 2023. In the event of multiple flush crops like cotton, only the harvest obtained on or before 31st January 2023 will be considered valid.
# ================
# ================
# Some crops have a short cropping season, and more than one crop can be cultivated in the kharif season eg. Moong plus cauliflower. A single gat can enter the data for more than one crop provided the entire gat is cultivating moong AND cauliflower as its major crop AND FURTHER PROVIDED that the harvest and all data entry has been completed on or before 31st January 2023.
#
# All the sections in Mulyankan Paddhat will be independently applicable to both the crops.
#
# 9. Prizes
# ================
# ================
# Prizes will be given to the gat. There will be 3 prizes at the state level. The first prize will be Rs. 25 lakhs, the second Rs. 15 lakh and the third prize will be Rs. 10 lakhs.
# ================
# ================
# There will also be a single prize of Rs 1 lakh at the taluka level. A gat winning a prize at the state level will not be eligible for a taluka level prize. A taluka level prize will be given subject to the gat getting at least 70% marks. Eg. If not a single gat in a taluka gets 70% marks in the competition, then no taluka level prize will be given for that taluka.
#
# No employee of the Paani Foundation or his/her family member will be eligible to win a prize.
#
# 10. Last Date for Participation
# ================
# ================
# In order to participate an eligible gat must complete the first stage of registration on or before 15th May 2022 and the second stage of registration on or before 31st May 2022.
#
# The competition will start on 15th May 2022.
#
# 11. Judging
# ================
# ================
# The data for the competition is to be filled by the farmers/gats on the Paani Foundation App. The data filled in by all gats/farmers who stand a chance of winning prizes will be verified by one or more teams appointed by Paani Foundation for that purpose. For this purpose, books of account and other documents will be examined, and individual members of the gat will be interviewed to verify information given by the gat. In particular the sales receipts will be examined and compared with prevailin
# ================
# ================
# g mandi prices at the time of sale. Gats which have deliberately falsified entries will be disqualified from the competition.
# ================
# ================
# Gats are expected to maintain photos/videos of the various activities that are part of this competition and also post these on the whatsapp group of the gat. These will be examined by the judges.
#
# The performance of the gat could be affected by climatic and natural calamities like drought, floods etc. Unfortunately, these cannot be captured by the rules of the competition and the results could be affected.
#
# 12. The decision taken by the judges will be final.
# ================
# ================
# MARKING SYSTEM AT A GLANCE
#
# Knowledge: 30 Marks
#
# Production Process: 30 Marks
#
# Sustainable Practices: 30 Marks
#
# Sale: 30 Marks
#
# Institution Building: 80 Marks
#
# Total = 200 Marks
#
# MARKING SYSTEM DETAILS
#
# I. KNOWLEDGE: 30 MARKS
#
# 1. Designing a System of Good Practices: 5 Marks
# ================
# ================
# Each gat must design a system of good practices - SOPs (Standard Operating Practices) to be followed by each farmer in the gat -- from soil preparation to harvesting and storage. 10 or more SOPs must be defined for the selected crop. These are practices that all members of the gat agree upon. Preparing this list of SOPs/good practices is necessary so that one can be prospective not reactive, so that one can plan to prevent problems rather than react after problems have occurred. It is a way towa
# ================
# ================
# rds making agriculture knowledge based. Here are a few examples of the subjects covered by the good practices:
# ================
# ================
# Pre-sowing field preparation, seed treatment, sowing method, plant spacing, nutrient management, weed management, water management, pest management, harvesting, storage of the crop.
#
# This creation of a list of SOPs/good practices for that particular crop must be done in consultation with experts - whether from the agricultural universities or progressive
# ================
# ================
# farmers or other experts. Paani Foundation will make all efforts to connect the gat with an expert/s. However, the gat will be at liberty to select their expert and the responsibility of creating the SOPs/good practices will be entirely that of the gat.
#
# The system of SOPs/good practices must be entered by the gat on the Paani Foundation App before cultivation commences. The gat will get 5 Marks for entering the SOPs/good practices on the Paani Foundation App.
# ================
# ================
# 2. Actual Implementation of Good Practices: 20 Marks
#
# The gat must enter on the Paani Foundation App which of the SOPs/good practices have been followed by each member of the gat.
# ================
# ================
# The gat will get marks in proportion to the percentage of SOPs followed by all the members of the gat. So eg. if the gat has planned to implement 10 SOPs and 100% of the members of the gat implement all 10 SOPs, then the gat will get full 20 Marks. If however only 8 of the SOPs have been implemented by all the members of the gat then the gat will get 16 Marks.
#
# If a gat has selected more than 10 SOPs but all its members have implemented at least 10 SOPs, then it will be entitled to get 20 marks.
# ================
# ================
# The photos and videos of the SOPs followed by the members of the Gat must be posted on the Gat's WhatsApp group. These photos and videos will be checked during the judging process.
#
# 3. Peer to peer learning and learning from Progressive Farmers: 5 Marks
# ================
# ================
# Improvement of productivity, improvement in quality and lowering of costs in agriculture is only possible through continuous improvements in the knowledge system of farmers. Peer to peer learning and exposure visits to progressive farmers is an important method of making the best knowledge available. 5 Marks will be given to gats that make the following efforts:
# ================
# ================
# i. Exposure visit to successful farmers cultivating this crop. Gats must enter the name of the progressive farmer and the date on which her/his field was visited. 1 mark will be given to a gat that does at least one such exposure visit to a successful farmer.
#
# The photos and videos of such an exposure visit done by the Gat must be posted on the Gat's WhatsApp group. These photos and videos will be checked during the judging process.
# ================
# ================
# ii. Shivarferi whereby gat members visit each other’s fields and closely observe each other’s fields. Gats must enter the dates on which the shivarferi is done. 1 marks will be given to a gat for every such shivarferi for a total of 3 marks.
#
# The photos and videos of such a shivarferi/s done by the Gat must be posted on the Gat's WhatsApp group. These photos and videos will be checked during the judging process.
# ================
# ================
# iii. A gat must have its own whatsapp group where they share information and photographs pertaining to their crop. They can share problems and solutions as part of peer-to-peer learning. This whatsapp group should not be used for forwards pertaining to entertainment, politics or other topics not pertaining to agriculture. 1 Mark will be given to a gat that maintains such a whatsapp group.
# ================
# ================
# II. PRODUCTION PROCESS: 30 MARKS
#
# 1. Joint Purchase of Inputs:10 marks
#
# Collective purchase of farming inputs helps drive down costs through economies of scale. Hence the purchase of farming inputs through the gat will be given marks in accordance with the table below.
#
# Percentage of farming inputs purchased through the gat
#
# Marks
#
# 75% +
#
# 10
#
# 60% + to 75%
#
# 8
#
# 50% + to 60%
#
# 6
#
# 40% + to 50%
#
# 4
#
# 30% ते 40%
#
# 2
# ================
# ================
# Less than 30
#
# 0
#
# The receipt of the vendor/s will certify that the purchase has been made on behalf of the gat. The information pertaining to the joint purchase by the gat as also the individual purchase by the member of the gat along with the supporting bills, receipts etc must be uploaded on the Paani Foundation App.
#
# 2. Joint Labour - Irjik: 20 Marks
# ================
# ================
# Shared labour or irjik is part of the rich tradition of our villages whereby farmers work on each other’s fields for key agricultural operations like sowing, weeding etc. Irjik creates trust and a deep bond between farmers. By bringing people together it also creates joy in the process of farming. The gat must enter for which agricultural process irjik has been done eg. Sowing, weeding etc. 4 marks will be given per process for which irjik is done. So if farmers in a gat do irjik for 5 agricultu
# ================
# ================
# ral processes then they will get full 20 marks. If they do irjik for only one process, then they will get only 4 marks.
# ================
# ================
# For such process, the irjik must have been done on the field of every farmer. It is not necessary for a member of the gat to participate in every single irjik, but every farmer in the gat must participate in at least some irjik. For any process which has been selected for Irjik, if even one farmer has not participated in irjik for that process or even one farmer has not had the benefit of a single irjik in his/her field for that process, the gat will get zero marks for that process. Work done fo
# ================
# ================
# r a fee will not be considered as shared labour.
# ================
# ================
# The photos and videos of all activities / work done by the Gat in this regard must be posted on the Gat's WhatsApp group. These photos and videos will be checked during the judging process.
#
# III. SUSTAINABLE PRACTICES: 30
#
# 1. Residue Free Farming: 20 marks
# ================
# ================
# Reducing the use of chemicals particularly pesticides, weedicides and fungicides is important for the consumer, farmer and agricultural labour and for our planet. Adoption of non-pesticide management is an important step in that direction. There are multiple practices that can help farmers avoid pesticides and weedicides ranging from multiple crops on a single field to the use of sticky traps and pheromone traps to the use of jeevamrut and various bio-pesticides.
# ================
# ================
# How good a particular method is can only be verified through the testing of agricultural produce for chemical residues. The government of India specifies the Maximum
#
# Residue Limit for each crop. The aim of the gat should be to ensure that every single farmer in the gat creates produce within the limits specified by the government. For this purpose the gat must organise a test at a government approved laboratory of a random sample of the produce of the gat and upload the results on the App.
# ================
# ================
# The method of selecting a random sample will be specified by a third-party agency approved by Paani Foundation.
#
# If this produce is within the MRL for that particular crop, the gat will get full 20 Marks. If the random sample tests more than the MRL then the gat will get zero marks under this section.
# ================
# ================
# Although the testing of produce will put a burden of cost on the gat, this certification of the produce as being within minimum residue limits will also help the gat achieve a premium price for their produce.
#
# 2. Percentage of Land Under Drip / Water-Saving Technologies: 5 marks
# ================
# ================
# The use of drip, sprinkler and mulching enables substantial water saving. The gat must specify if the member farmers are using one or more of any these methods and for what extent of the land. The gat will be awarded marks as per the extent of land under water saving technologies in accordance with the table below.
#
# Percentage of irrigated land under water saving technologies
#
# Marks
#
# 75% +
#
# 5
#
# 70% + ते 75%
#
# 4
#
# 65% + ते 70%
#
# 3
#
# 60% + ते 65%
#
# 2
#
# 55% ते 60%
#
# 1
# ================
# ================
# Less than 55%
#
# 0
#
# Any extent of land that is entirely rain fed and not under irrigation is excluded for the purposes of this section.
#
# Members of the gat must take photos/videos of the work done under this Section and post these on the gat’s whatsapp Group. These will be examined during the judging process.
#
# 3. Matchbox Free Village: 5 Marks
# ================
# ================
# 5 Marks will be given to a gat that composts all of its crop residue by one method or another and does not burn any crop residue. Crop residues may be ploughed into the soil or be turned into slurry through bio-methanation or through the use of bio dynamix, or waste decomposer or NADEP. The method through which the crop residue is composted may be selected by an individual farmer so long as no crop residue is burnt. To get full marks in this section, every member of the gat must implement one of
# ================
# ================
#  the methods mentioned above. The gat must enter in the App what is done to the crop remains for every member of the gat. Every member of the gat should take photos/videos regarding the same and post these on the gat’s whatsapp group. These will be examined during the judging process.
# ================
# ================
# IV. SALE: 30 Marks
#
# 1. Collective Efforts for Sale: 10 Marks
# ================
# ================
# One of the important purposes for which a gat is established is to achieve better price realisation for the crop using its collective strength. For this purpose, it is important that the gat gets together to sell its produce. Every farmer must as part of the spardha enter data pertaining to his/her revenue on the Paani Foundation App. The sum total of the revenue of every member of the gat amounts to the total revenue of the gat. The gat must specify how much of the total revenue of the gat was
# ================
# ================
# obtained by collective sale as a gat along with supporting bills and documents. Marks will be given to the gat depending on the percentage of the total revenue of the gat obtained by collective sale as a gat. These marks will be given in accordance with the table below.
# ================
# ================
# Percentage of the total revenue of the gat that is obtained by collective sale as a gat
#
# Marks
#
# 75% +
#
# 10
#
# 60% + to 75%
#
# 8
#
# 50% + to 60%
#
# 6
#
# 40% + to 50%
#
# 4
#
# 30% to 40%
#
# 2
# ================
# ================
# Less than 30%
#
# 0
#
# If farmers have stored their produce for better price realisation later, they should produce the relevant documents establishing this. For any non-perishable produce that has been safely stored and not sold the sale price will be assumed to be the prevailing mandi price on 31st January 2023. Similarly, if the Gat plans to collectively sell the produce in future, it should specify that in the app.
# ================
# ================
# In the case of maize that is converted into silage for self use by the dairy farmer the sale price of the silage is assumed to be Rs. 5/- kg. This assumption is being made since there will be no bill for sale to one’s own self.
#
# 2. Value Addition. 15 Marks
# ================
# ================
# Every crop carries with it the possibility of value addition in one form or another. Eg. millets can be turned into flour and various products made out of millets. Maize can be processed into silage. In all crops, cleaning and grading offers the possibility of value addition. Cleaning and grading of produce and all forms of value addition help the farmer get better prices in the market. It also helps establish the reputation of the gat. 15 Marks will be given to the gat that does value addition
# ================
# ================
# to its crop. If the gat does value addition to only a part of the produce of the farmers it will get marks in proportion to the extent to which such value addition has been done.
# ================
# ================
# E.g. If the total production of the Gat is 100 quintals of which value addition has been done for 50 quintals, then the Gat will get 7.5 marks in this category.
#
# The photos and videos of all activities / work done by the Gat in this regard must be posted on the Gat's WhatsApp group. These photos and videos will be checked during the judging process.
#
# 3. Arrangements for Storage: 5 marks
# ================
# ================
# Often prices crash during the harvest period but go up once the harvest period is over. Proper arrangements for storage are critical to being able to achieve a proper price for the product. Storage with warehouse receipts can also enable farmers to get a cash flow and hold onto their produce till they get a proper price. A lot of storage
# ================
# ================
# arrangements are available on rent but an individual farmer is not able to spend the money on transport or on rent. Making arrangements for storage is therefore a critical part of the functioning of a gat. For this purpose, a gat must show documentation that establishes that the gat has gathered information about available storage and made arrangements for such storage which includes information about the cost of such storage, when it would be made available and the volume of such availability.
# ================
# ================
# The decision whether to use such storage would be that of the individual farmer. 5 marks will be given to a gat which makes arrangements for storage. Please note these marks will be given whether or not farmers actually use these storage arrangements.
# ================
# ================
# Since Onion, Tomato, Cauliflower, Cabbage and other vegetables are highly perishable, storage arrangements are not viable for these crops and hence gats cultivating these crops will get full 5 marks under this Section.
#
# If storage is arranged at home, it should be recorded on the Paani Foundation app and the photos / videos should be posted on the WhatsApp group. These photos and videos will be checked during the judging process.
# ================
# ================
# V. GAT AS AN INSTITUTION: 80 Marks
#
# 1. Accounts of the Gat: 2.5 Marks
#
# A proper functioning gat is a business unit that must maintain proper books of account. The joint purchase of inputs, the contributions of Members for these inputs, the realisations from sale of the crop etc. must all be reflected in the books of account which must be entered on the Paani Foundation App.
# ================
# ================
# Hence, if proper books of account of the gat are not maintained, then it is not possible to calculate marks for several other sections in the competition eg. Joint Purchase of inputs: 10 Marks, Joint Efforts for Sale: 10 Marks, Value Addition: 15 Marks etc.
#
# If proper books of account of the gat are not maintained then there will be no option but to give zero marks for each of these sections.
#
# 2. Bank Account of the Gat : 2.5 Marks
# ================
# ================
# The gat must have a bank account for which it will get 2.5 Marks.
#
# 3. Farmers Books of Account Marks: 10 Marks
# ================
# ================
# Every individual farmer who is part of the gat is running a business and hence must keep books of account. 10 Marks will be given if every farmer in the gat maintains books of account via the Paani Foundation App. If only some members of the gat maintain books of account then the gat will get marks in proportion to the number of farmers maintaining books of account. Eg. In a gat with 20 members only 10 members maintain books of account, then the gat will get 5 marks.
# ================
# ================
# A farmer must make ALL the entries - from pre-sowing operations to transport for sale in the books of account to get marks under this Section.
#
# If all the members of the gat do not make all the entries on the Paani Foundation App as required by this Section, it is not possible to calculate marks for several other sections in the competition eg. Joint Purchase of inputs: 10 Marks, Joint Efforts for Sale: 10 Marks, Value Addition: 15 Marks, Profit of the gat : 40 Marks etc.
# ================
# ================
# If all the members of the gat do not make all the entries on the Paani Foundation App as required by this section, then there will be no option but to give zero marks for each of these sections.
#
# 4) Cost-Revenue for Previous Kharif Crop - 5 marks
# ================
# ================
# Writing the cost, revenue and yield for the previous kharif season will help farmers know whether or not this year’s farming is a step in the right direction. Hence marks will be given for entering this data for the previous kharif crop in accordance with the table below.
#
# Percentage of Members of the gat who enter cost, revenue yield data for the previous Kharif Crop
#
# Marks
#
# 50% +
#
# 5
#
# 40% + to 50%
#
# 4
#
# 30% + to 40%
#
# 3
#
# 20% + to 30%
#
# 2
#
# 10% to 20%
#
# 1
# ================
# ================
# Less than 10%
#
# 0
#
# Receipts / documents of Accounts are not expected in this regard.
#
# 5. Inter-gat Cooperation: 5 Marks
# ================
# ================
# The present gats are a stepping stone to large farmer producer organisations. The ultimate goal is an FPO - whether under the Companies Act or the Cooperative Societies Act which has the economies of scale necessary to solve all the problems of farmers. This requires farmers with at least 1,000 acres of land coming together. This cannot be achieved overnight. As a first step the gats competing in this competition should cooperate with other gats in the matter of purchase of inputs, sale of crop,
# ================
# ================
#  marketing arrangements or any other matter that forms a part of this spardha.
# ================
# ================
# The competing gats must enter on the App the various activities for which they have entered into inter-gat cooperation along with supporting documents. For each such activity, 2.5 marks will be allotted. A total of 5 Marks will be allotted for inter-gat cooperation.
#
# 6. Contribution to Community Work: 5 Marks
# ================
# ================
# The gat is a part of the village and both benefits from and contributes to the overall well-being of the village. Gats can contribute to the village through shramdan for tree plantation, creation and maintenance of grasslands or any other activity that is a part of the Samruddha Gaav Spardha. The gat must enter on the App which of such activities the gat has participated in. Participation in 2 or more activities of the village will be given 5 marks. The Gat will receive 2.5 marks for each such a
# ================
# ================
# ctivity. The group will get a maximum of 5 marks under this section.
# ================
# ================
# The photos and videos of all activities / work done by the Gat in this regard must be posted on the Gat's WhatsApp group. These photos and videos will be checked during the judging process.
#
# 7. Profitability of the Gat (40 marks)
# ================
# ================
# A gat is first and foremost an economic entity. Its success or failure and indeed its possibility of survival or growth will depend on its performance as an economic entity. The Profit and Loss statement of the gat will reveal its performance as an economic entity. Marks under this Section will be given under the headings of profit per acre and percentage of profits. The profits will be calculated in the following manner.
# ================
# ================
# The Planning Department, Government of Maharashtra through the Directorate of Statistics and Economics in June 2021 published its final report on the cost and revenue of various crops. Accordingly, a table giving the cost of production per acre of each crop is given in the appendix at the end of this document.
#
# This report is available via this link: https://mahades.maharashtra.gov.in/surveyReports.do?repCatId=CFA
# ================
# ================
# Using the costs given in the table above as a benchmark, the Paani Foundation App will calculate the cost of cultivation incurred by the gat in the following manner:
#
# Total cost of cultivation of the gat = Average cost of cultivation per the table above in Rs/acre x Number of acres cultivated by the gat
# ================
# ================
# In addition if the gat does value addition eg. converting maize into silage, then the costs pertaining to such conversion/value addition must be added. In further addition, the gat incurs costs pertaining to sale of the produce eg. cost of transport of handling, weighing and commission paid to traders. In case of safe storage of agricultural produce without sale till 31st January 2023, these expenses will be charged according to the rates available in the taluka market.
# ================
# ================
# Hence: Total cost of the gat = Total Cost of cultivation + Cost of Value addition (if any) + Costs incurred for sale.
#
# Now let’s see how the revenue of the gat is calculated.
#
# Total revenue of the gat = Sum of revenue from sale of the main crop by each farmer + Sum of revenue from sale of the intercrop by each farmer + Sum of revenue from sale of the by-product (eg. soybean straw) by each farmer + Sum of revenue from sale of the value added product (if any) by each farmer
# ================
# ================
# On this basis, the profit percentage and also profit/acre for each gat will be calculated.
#
# Profit of the gat = Total revenue of the gat – Total Cost of cultivation of the gat
#
# Profit percentage = Profit of the gat/Total Cost of the Gat x 100
#
# Profit/Acre = Profit of the Gat/Number of Acres under cultivation by the gat
#
# 20 marks are allocated for Profit/acre and 20 Marks forProfit Percentage.
#
# A. Profit per acre (Rs)
#
# Profit per acre (Rs)
# ================
# ================
# Marks
#
# 50,000 +
#
# 20
#
# 40,000 + to 50,000
#
# 16
#
# 30,000 + to 40,000
#
# 12
#
# 20,000+ to 30,000
#
# 8
#
# 10,000+ to 20,000
#
# 4
#
# 10,000 or less
#
# 0
#
# B. Profit percentage
#
# Profit percentage
#
# Marks
#
# 100%+
#
# 20
#
# 60%+ to 100%
#
# 15
#
# 40%+ to 60%
#
# 12
#
# 25%+ to 40%
#
# 8
#
# 10%+ to ते 25%
#
# 5
#
# 10% or less
#
# 0
#
# 8. Team Work, Leadership and Vision: 10 Marks
# ================
# ================
# A gat is a collection of human beings each with their own background, thoughts and points of view. One of the biggest challenges of the gat is good team work. How does a gat handle differences? What is its vision? What is the quality of leadership?. All these factors contribute greatly to the success or failure of the gat. All gats that stand a chance of winning a prize in the competition on the basis of all the other heads above will be judged on this criteria by Paani Foundation judges appoint
# ================
# ================
# ed for this purpose. 10 Marks have been allocated under this section.
# ================
# ================
# APPENDIX
#
# Name of Crop
#
# Production Cost/Acre in Rs Based on Govt. of Maharashtra Data
#
# Bajra
#
# 14317.39
#
# Maize
#
# 24302.07
#
# Kh. Paddy
#
# 23260.31
#
# Kh. Jowar
#
# 18182.56
#
# Ragi
#
# 11099.19
#
# Tur
#
# 22604.45
#
# Moong
#
# 17638.09
#
# Udid
#
# 15482.25
#
# Groundnut
#
# 32588.52
#
# Soybean
#
# 20718
#
# Cotton
#
# 26476.78
#
# Coriander Seed
#
# 17236.61
#
# Ajwain
#
# 27852
#
# Beans
#
# Cabbage
#
# Cauliflower
#
# Capsicum
#
# Brinjal
#
# Okra
#
# Kh. Onion
#
# Ivy gourd
#
# Potato
#
# Sweet Potato
#
# Pumpkin
#
# Tomato
#
# Bitter gourd
#
# Bottle gourd
#
# Pointed gourd
#
# Ridge gourd
# ================
# ================
# Sponge gourd
#
# Peas
#
# Green Chili
#
# Coriander
#
# Fenugreek
#
# Leafy Veg. (Spinach)
#
# Other Veg. (Cluster bean)
# ================
# ================
# LIST OF SOPs
#
# A. पूवमशागत १. उताराला आडवी नांगरणी करणे. २. उहात नांगरणी करणे. ३. पूण कु जलेले शेणखत मातीआड करणे.
#
# 70910.82
#
# 63710.1
#
# 60283.5
#
# 96244.67
#
# 75618.92
#
# 50973.45
#
# 38976.16
#
# 68330.43
#
# 89096.67
#
# 47356.71
#
# 75348.73
#
# 82125.69
#
# 74200.78
#
# 46990.83
#
# 45223.84
#
# 63444.83
#
# 75829.71
#
# 38214.89
#
# 70140.69
#
# 23554.54
#
# 25019.89
#
# 28404.51
#
# 29119.35
#
# B. बयाणे नवड १. उपलध वाणांचा अयास करणे. २. बयायाची उगवण मता तपासणी करणे. ३. बीजया करणे.
# ================
# ================
# C. पेरणी १. BBF पधतीने पेरणी करणे. २. सर वरंबा / गाद वायावर टोकन पधतीने पेरणी करणे. ३. पकांया दोन ओळी व रोपांमये योय अंतर ठे वणे.
#
# D. खतयवथापन १. माती परण करणे. २. माती परणानुसार खतांचा योय वापर करणे. ३. जीवामृत आण वाय खतांचा योय वापर करणे.
#
# E. तणनयंण १. सायकल कोळपे, हात कोळपे, खुरपणी वारे तणनयंण करणे.
#
# F. पाणी यवथापन १. ठबक संचन / तुषार संचन वारे पाणी देणे. २. आछादन करणे.
# ================
# ================
# G. कडयवथापन १. चकट सापळे वापरणे. २. काश सापळे वापरणे. ३. कामगंध सापळे वापरणे. ४. पीथांबे तयार करणे. ५. जैवक कटकनाशकांचा वापर करणे. ६. जैवक बुरशीनाशकांचा वापर करणे. ७. सापळा पके घेणे.
# ================

# %%
for chunk in chunks:
  print("===================")
  print(chunk)
  print(chunk.metadata.filename)
  print(chunk.metadata.file_directory)
  # print(chunk.metadata.is_continuation)
  print(chunk.metadata.parent_id)

  print("===================")

# %%
for i in x:
  print("================")
  print(i)
  print("================")

# %%
def chunk_by_title_with_overlap(elements, overlap):
   chunks = chunk_by_title(elements)
   overlapped_chunks = []

   for i in range(len(chunks) - 1):
       chunks[i].text += chunks[i + 1].text[:overlap]
       chunks[i + 1].text = chunks[i + 1].text[overlap:]
       overlapped_chunks.append(chunks[i])
      #  print(chunks[i])

   overlapped_chunks.append(chunks[-1])
   return overlapped_chunks

chunk_by_title_with_overlap(elements,100)
# Out:
# [<unstructured.documents.elements.CompositeElement at 0x7f2d74821ed0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748237f0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d74822980>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d74823fa0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d74823130>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748221a0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748219c0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d747b5270>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748daa10>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d747b74c0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748d9780>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748db250>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748dae30>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748db0d0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748daf50>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748d9fc0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748d9d50>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d747b56c0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d747b6a10>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d747b7a90>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748dba60>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748dbf10>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748db700>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748da680>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748db3a0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748da2c0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d76a99840>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748db6d0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748da6e0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748da410>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d76a98760>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d76a98e20>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d76a98820>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d76a98700>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d76a98640>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d76a98ee0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d76a99a80>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d76a98f10>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d76a999c0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d76a991e0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d76a99540>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d76a98430>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d76a98610>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481e470>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481e260>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481e320>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481e2f0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481e230>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481e1d0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481dfc0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481df90>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481e2c0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481e080>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481e110>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481de70>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481df30>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481dc30>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481dcc0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481dc90>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481dbd0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481dd20>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481db10>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d9f0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d990>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481da80>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d960>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d840>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d7e0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d780>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d6c0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d5d0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d570>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d420>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d3f0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d450>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d390>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d330>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d240>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d3c0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d1e0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d0c0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d060>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481d000>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481cfa0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481cee0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481cc10>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481cac0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481cbe0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481ca30>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481c040>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481c970>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481c9a0>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d7481ca60>,
#  <unstructured.documents.elements.CompositeElement at 0x7f2d748227d0>]

# %%
def chunk_by_title_with_overlap(elements, overlap):
  chunks = chunk_by_title(elements)
  overlapped_chunks = []

  for i in range(len(chunks) - 1):
      chunks[i].text = str(chunks[i].text)
      chunks[i + 1].text = str(chunks[i + 1].text)
      chunks[i].text += chunks[i + 1].text[:overlap]
      chunks[i + 1].text = chunks[i + 1].text[overlap:]
      overlapped_chunks.append(chunks[i])

  overlapped_chunks.append(chunks[-1])
  return overlapped_chunks
x = chunk_by_title_with_overlap(elements,100)

# %%
for i in x:
  print("================")
  print(i.text)
  print("================")
# Out:
# ================
# Satyamev Jayate Farmer Cup: Marking SystemThe lone farmer survives from one crisis to the next. From poor quality seeds to drought to a collap
# ================
# ================
# se of market prices, there is danger lurking at every step. A farmer cannot solve these problems alone. However, Farmer Producer Organisations owned by large numbers of farmers can use their collective strength to solve these problems. Amul and Sahyadri Agro are a few examples of Farmer Producer Organisations who have proved that collectivisation of farming can create the eco-system necessary for farming to thrive. These models can and must be replicated on a massive scale. However, these models
# ================
# ================
#  only work if they have a strong foundation and are built from the ground up. The gat is the first step which must be built and strengthened. This competition aims to motivate and train farmers in the process of collectivisation. It aims to start farmers on the journey from debt to prosperity.KEY GOALS FOR STAGE 1
#
# 1. Create demos/models that will demonstrate that only through collectivisati
# ================
# ================
# on can farmers solve their problems.
#
# 2. To rekindle enthusiasm and joy in farming through collectivism.
#
# 3. To identify good gats. These gats will serve as the stepping stone to larger gats/FPCs which will be able to solve increasingly larger and more complex problems faced by farmers.4. To identify good leadership within the gats, in other words to find and nurture entrepreneurs who
# ================
# ================
#  have the right motivation, vision and capability to create larger gats/FPCs which can solve increasingly larger problems faced by farmers.
#
# 5. To create financial literacy among farmers by making them aware of the detailed costs and revenue of their crop.RULES FOR THE COMPETITION
#
# 1. Cropwise Gat
#
# The gat must be of farmers cultivating a single crop. Fa
# ================
# ================
# rmers in a gat may cultivate more than one crop, however all farmers in the gat must cultivate the crops in the same ratio.
#
# Eg. A gat which cultivates soybean as the main crop with 4 lines and tur as the intercrop with 2 lines should fill the entry form for the competition in the soybean category provided all farmers in the gat cultivate soybean and tur in the same ratio of 4:2.A single farmer can be a member of more than one gat. A farmer can be a member of only one gat for a
# ================
# ================
# ny particular crop. However, each of these gats must be formed for a single crop.
#
# 2. Multi-village Gats
#
# The farmers in a single gat may be from more than one village which are proximate to each other.
#
# 3. Minimum AreaThe minimum land under gat cultivation for that particular crop should not be less than 25 acres. Ho
# ================
# ================
# wever, all 25 or more acres should be assigned for selling crops/produce in the market. Crops grown for personal consumption should not be part of these 25 or more acres. Having a minimum of 25 acres under cultivation enables a gat to utilise economies of scale in purchase of inputs and sale of the crop. A single farmer in the gat should not have more than half the land under cultivation in the gat.
# ================
# ================
# 4. Minimum Number of Farmers There must be a minimum number of at least 20 farming families in the g
# ================
# ================
# at. Every family which is a single economic group will be considered as a single farming family even if there are more than one khatedaars in the family.
#
# 5. Process of Participation in the Competition by the Gat
#
# The process of participation in the competition is in two stages.Stage 1: Any group of farmers that wants to participate in the competition must click on the link pr
# ================
# ================
# ovided by Paani Foundation and fill the Entry form in which they specify the following: Name of the gat, Crop to be cultivated, Names of 3 Convenors (Nimantraks) of the gat, with whatsapp no. and size of land on which the selected crop is being cultivated.Stage 2: Each of the convenors will be sent a link that will enable the names of the remaining membe
# ================
# ================
# rs of the gats to be entered along with their cell number and area under cultivation. These details must be entered on or before 15th May 2022. It is only after Stage 2 is completed in accordance with the rules that the gat will be admitted into the competition.The members of a gat may be men or women. Existing Women Self Help Groups or Atma Groups are eligibl
# ================
# ================
# e to participate. However, government registration is not compulsory when enrolling for the competition.
#
# 6. Talukas and villages in the CompetitionThis competition is a part of the Satyamev Jayate Samruddha Gaav Spardha. Hence, the members of the
# ================
# ================
# gat must be from one of the 39 talukas and participating villages in the Samruddha Gaav Spardha. However, a maximum of 25% of the members of a gat can be from villages that are not participating in the Samruddha Gaav Spardha but are adjoining such villages provided that all the Nimantraks (Convenors) of the gat are from Samruddha Gaav Villages. A taluka will be eligible to participate in the competition subject to a minimum of 10 gats from the taluka participating in the competition.
# ================
# ================
# 7. Crops in the Competition
#
# For the purposes of the competition, the following major kharif crops a
# ================
# ================
# re included:
#
# 01. Bajri 02. Maize 03. Paddy 04. Jwari 05. Ragi 06. Tur 07. Moong 08. Udid 09. Groundnut 10. Soyabean 11. Cotton 12. Coriander seeds 13. Ajwain 14. Beans 15. Cabbage 16. Cauliflower 17. Capscicum18. Brinjal 19. Okra 20. Onion 21. Ivy Gourd 22. Potato 23. Sweet Potato 24. Pumpkin 25. Tomato 26.
# ================
# ================
# Bitter Gourd 27. Bottle Gourd 28. Pointed Gourd 29. Ridged Gourd 30. Spongy Gourd 31. Peas 32. Chilli 33. Coriander 34. Fenugreek 35. Spinach 36. Cluster BeansThe Department of Planning Government of Maharashtra through its Directorate of Statistics and Econo
# ================
# ================
# mics has published the results of a survey of the cost and revenue data of various crops in Maharashtra. These are the crops included in this competition.
#
# 8. Kharif Season-End DateFor the purposes of this competition, harvesting must be completed and data entered on or before 31s
# ================
# ================
# t January 2023. In the event of multiple flush crops like cotton, only the harvest obtained on or before 31st January 2023 will be considered valid.Some crops have a short cropping season, and more than one crop can be cultivated in the kharif seas
# ================
# ================
# on eg. Moong plus cauliflower. A single gat can enter the data for more than one crop provided the entire gat is cultivating moong AND cauliflower as its major crop AND FURTHER PROVIDED that the harvest and all data entry has been completed on or before 31st January 2023.
#
# All the sections in Mulyankan Paddhat will be independently applicable to both the crops.
#
# 9. PrizesPrizes will be given to the gat. There will be 3 prizes at the state level. The first prize will be
# ================
# ================
# Rs. 25 lakhs, the second Rs. 15 lakh and the third prize will be Rs. 10 lakhs.There will also be a single prize of Rs 1 lakh at the taluka level. A gat winning a prize at the sta
# ================
# ================
# te level will not be eligible for a taluka level prize. A taluka level prize will be given subject to the gat getting at least 70% marks. Eg. If not a single gat in a taluka gets 70% marks in the competition, then no taluka level prize will be given for that taluka.
#
# No employee of the Paani Foundation or his/her family member will be eligible to win a prize.
#
# 10. Last Date for ParticipationIn order to participate an eligible gat must complete the first stage of registration on or before 1
# ================
# ================
# 5th May 2022 and the second stage of registration on or before 31st May 2022.
#
# The competition will start on 15th May 2022.
#
# 11. JudgingThe data for the competition is to be filled by the farmers/gats on the Paani Foundation App. The da
# ================
# ================
# ta filled in by all gats/farmers who stand a chance of winning prizes will be verified by one or more teams appointed by Paani Foundation for that purpose. For this purpose, books of account and other documents will be examined, and individual members of the gat will be interviewed to verify information given by the gat. In particular the sales receipts will be examined and compared with prevailing mandi prices at the time of sale. Gats which have deliberately falsified entries will be disqualif
# ================
# ================
# ied from the competition.Gats are expected to maintain photos/videos of the various activities that are part of this competit
# ================
# ================
# ion and also post these on the whatsapp group of the gat. These will be examined by the judges.
#
# The performance of the gat could be affected by climatic and natural calamities like drought, floods etc. Unfortunately, these cannot be captured by the rules of the competition and the results could be affected.
#
# 12. The decision taken by the judges will be final.MARKING SYSTEM AT A GLANCE
#
# Knowledge: 30 Marks
#
# Production Process: 30 Marks
#
# Sustainable Practices
# ================
# ================
# : 30 Marks
#
# Sale: 30 Marks
#
# Institution Building: 80 Marks
#
# Total = 200 Marks
#
# MARKING SYSTEM DETAILS
#
# I. KNOWLEDGE: 30 MARKS
#
# 1. Designing a System of Good Practices: 5 MarksEach gat must design a system of good practices - SOPs (Standard Operating Practices) to be followed
# ================
# ================
#  by each farmer in the gat -- from soil preparation to harvesting and storage. 10 or more SOPs must be defined for the selected crop. These are practices that all members of the gat agree upon. Preparing this list of SOPs/good practices is necessary so that one can be prospective not reactive, so that one can plan to prevent problems rather than react after problems have occurred. It is a way towards making agriculture knowledge based. Here are a few examples of the subjects covered by the good
# ================
# ================
# practices:Pre-sowing field preparation, seed treatment, sowing method, plant spacing, nutrient management, wee
# ================
# ================
# d management, water management, pest management, harvesting, storage of the crop.
#
# This creation of a list of SOPs/good practices for that particular crop must be done in consultation with experts - whether from the agricultural universities or progressivefarmers or other experts. Paani Foundation will make all efforts to connect the gat with an expert/s
# ================
# ================
# . However, the gat will be at liberty to select their expert and the responsibility of creating the SOPs/good practices will be entirely that of the gat.
#
# The system of SOPs/good practices must be entered by the gat on the Paani Foundation App before cultivation commences. The gat will get 5 Marks for entering the SOPs/good practices on the Paani Foundation App.2. Actual Implementation of Good Practices: 20 Marks
#
# The gat must enter on the Paani Foundation App
# ================
# ================
#  which of the SOPs/good practices have been followed by each member of the gat.The gat will get marks in proportion to the percentage of SOPs followed by all the members of the ga
# ================
# ================
# t. So eg. if the gat has planned to implement 10 SOPs and 100% of the members of the gat implement all 10 SOPs, then the gat will get full 20 Marks. If however only 8 of the SOPs have been implemented by all the members of the gat then the gat will get 16 Marks.
#
# If a gat has selected more than 10 SOPs but all its members have implemented at least 10 SOPs, then it will be entitled to get 20 marks.The photos and videos of the SOPs followed by the members of the Gat must be posted on the Gat's Wha
# ================
# ================
# tsApp group. These photos and videos will be checked during the judging process.
#
# 3. Peer to peer learning and learning from Progressive Farmers: 5 MarksImprovement of productivity, improvement in quality and lowering of costs in agriculture is only pos
# ================
# ================
# sible through continuous improvements in the knowledge system of farmers. Peer to peer learning and exposure visits to progressive farmers is an important method of making the best knowledge available. 5 Marks will be given to gats that make the following efforts:i. Exposure visit to successful farmers cultivating this crop. Gats must enter the name of the progr
# ================
# ================
# essive farmer and the date on which her/his field was visited. 1 mark will be given to a gat that does at least one such exposure visit to a successful farmer.
#
# The photos and videos of such an exposure visit done by the Gat must be posted on the Gat's WhatsApp group. These photos and videos will be checked during the judging process.ii. Shivarferi whereby gat members visit each other’s fields and closely observe each other’s fields
# ================
# ================
# . Gats must enter the dates on which the shivarferi is done. 1 marks will be given to a gat for every such shivarferi for a total of 3 marks.
#
# The photos and videos of such a shivarferi/s done by the Gat must be posted on the Gat's WhatsApp group. These photos and videos will be checked during the judging process.iii. A gat must have its own whatsapp group where they share information and photographs pertaining
# ================
# ================
# to their crop. They can share problems and solutions as part of peer-to-peer learning. This whatsapp group should not be used for forwards pertaining to entertainment, politics or other topics not pertaining to agriculture. 1 Mark will be given to a gat that maintains such a whatsapp group.II. PRODUCTION PROCESS: 30 MARKS
#
# 1. Joint Purchase of Inputs:10 marks
#
# Collective purchase of farmi
# ================
# ================
# ng inputs helps drive down costs through economies of scale. Hence the purchase of farming inputs through the gat will be given marks in accordance with the table below.
#
# Percentage of farming inputs purchased through the gat
#
# Marks
#
# 75% +
#
# 10
#
# 60% + to 75%
#
# 8
#
# 50% + to 60%
#
# 6
#
# 40% + to 50%
#
# 4
#
# 30% ते 40%
#
# 2Less than 30
#
# 0
#
# The receipt of the vendor/s will certify that the purchase has been made on behalf
# ================
# ================
# of the gat. The information pertaining to the joint purchase by the gat as also the individual purchase by the member of the gat along with the supporting bills, receipts etc must be uploaded on the Paani Foundation App.
#
# 2. Joint Labour - Irjik: 20 MarksShared labour or irjik is part of the rich tradition of our villages whereby farmers work on each ot
# ================
# ================
# her’s fields for key agricultural operations like sowing, weeding etc. Irjik creates trust and a deep bond between farmers. By bringing people together it also creates joy in the process of farming. The gat must enter for which agricultural process irjik has been done eg. Sowing, weeding etc. 4 marks will be given per process for which irjik is done. So if farmers in a gat do irjik for 5 agricultural processes then they will get full 20 marks. If they do irjik for only one process, then they wil
# ================
# ================
# l get only 4 marks.For such process, the irjik must have been done on the field of every farmer. It is not necessary fo
# ================
# ================
# r a member of the gat to participate in every single irjik, but every farmer in the gat must participate in at least some irjik. For any process which has been selected for Irjik, if even one farmer has not participated in irjik for that process or even one farmer has not had the benefit of a single irjik in his/her field for that process, the gat will get zero marks for that process. Work done for a fee will not be considered as shared labour.
# ================
# ================
# The photos and videos of all activities / work done by the Gat in this regard must be posted on the
# ================
# ================
# Gat's WhatsApp group. These photos and videos will be checked during the judging process.
#
# III. SUSTAINABLE PRACTICES: 30
#
# 1. Residue Free Farming: 20 marksReducing the use of chemicals particularly pesticides, weedicides and fungicides is important for th
# ================
# ================
# e consumer, farmer and agricultural labour and for our planet. Adoption of non-pesticide management is an important step in that direction. There are multiple practices that can help farmers avoid pesticides and weedicides ranging from multiple crops on a single field to the use of sticky traps and pheromone traps to the use of jeevamrut and various bio-pesticides.How good a particular method is can only be verified through the testing of agricultural produce for
# ================
# ================
#  chemical residues. The government of India specifies the Maximum
#
# Residue Limit for each crop. The aim of the gat should be to ensure that every single farmer in the gat creates produce within the limits specified by the government. For this purpose the gat must organise a test at a government approved laboratory of a random sample of the produce of the gat and upload the results on the App.The method of selecting a random sample will be specified by a third-party agency approved by Paani
# ================
# ================
# Foundation.
#
# If this produce is within the MRL for that particular crop, the gat will get full 20 Marks. If the random sample tests more than the MRL then the gat will get zero marks under this section.Although the testing of produce will put a burden of cost on the gat, this certification of the prod
# ================
# ================
# uce as being within minimum residue limits will also help the gat achieve a premium price for their produce.
#
# 2. Percentage of Land Under Drip / Water-Saving Technologies: 5 marksThe use of drip, sprinkler and mulching enables substantial water saving. The gat must specify if th
# ================
# ================
# e member farmers are using one or more of any these methods and for what extent of the land. The gat will be awarded marks as per the extent of land under water saving technologies in accordance with the table below.
#
# Percentage of irrigated land under water saving technologies
#
# Marks
#
# 75% +
#
# 5
#
# 70% + ते 75%
#
# 4
#
# 65% + ते 70%
#
# 3
#
# 60% + ते 65%
#
# 2
#
# 55% ते 60%
#
# 1Less than 55%
#
# 0
#
# Any extent of land that is entirely rain fed and not under irrigation is excluded
# ================
# ================
# for the purposes of this section.
#
# Members of the gat must take photos/videos of the work done under this Section and post these on the gat’s whatsapp Group. These will be examined during the judging process.
#
# 3. Matchbox Free Village: 5 Marks5 Marks will be given to a gat that composts all of its crop residue by one method or another and do
# ================
# ================
# es not burn any crop residue. Crop residues may be ploughed into the soil or be turned into slurry through bio-methanation or through the use of bio dynamix, or waste decomposer or NADEP. The method through which the crop residue is composted may be selected by an individual farmer so long as no crop residue is burnt. To get full marks in this section, every member of the gat must implement one of the methods mentioned above. The gat must enter in the App what is done to the crop remains for eve
# ================
# ================
# ry member of the gat. Every member of the gat should take photos/videos regarding the same and post these on the gat’s whatsapp group. These will be examined during the judging process.IV. SALE: 30 Marks
#
# 1. Collective Efforts for Sale: 10 Marks
# ================
# ================
# One of the important purposes for which a gat is established is to achieve better price realisation
# ================
# ================
# for the crop using its collective strength. For this purpose, it is important that the gat gets together to sell its produce. Every farmer must as part of the spardha enter data pertaining to his/her revenue on the Paani Foundation App. The sum total of the revenue of every member of the gat amounts to the total revenue of the gat. The gat must specify how much of the total revenue of the gat was obtained by collective sale as a gat along with supporting bills and documents. Marks will be given
# ================
# ================
# to the gat depending on the percentage of the total revenue of the gat obtained by collective sale as a gat. These marks will be given in accordance with the table below.Percentage of the total revenue of the gat that is obtained by collective sale as a gat
#
# Marks
#
# 75%
# ================
# ================
# +
#
# 10
#
# 60% + to 75%
#
# 8
#
# 50% + to 60%
#
# 6
#
# 40% + to 50%
#
# 4
#
# 30% to 40%
#
# 2Less than 30%
#
# 0
#
# If farmers have stored their produce for better price realisation later, they shou
# ================
# ================
# ld produce the relevant documents establishing this. For any non-perishable produce that has been safely stored and not sold the sale price will be assumed to be the prevailing mandi price on 31st January 2023. Similarly, if the Gat plans to collectively sell the produce in future, it should specify that in the app.In the case of maize that is converted into silage for self use by the dairy farmer the sale price o
# ================
# ================
# f the silage is assumed to be Rs. 5/- kg. This assumption is being made since there will be no bill for sale to one’s own self.
#
# 2. Value Addition. 15 MarksEvery crop carries with it the possibility of value addition in one form or another. Eg. millets can
# ================
# ================
#  be turned into flour and various products made out of millets. Maize can be processed into silage. In all crops, cleaning and grading offers the possibility of value addition. Cleaning and grading of produce and all forms of value addition help the farmer get better prices in the market. It also helps establish the reputation of the gat. 15 Marks will be given to the gat that does value addition to its crop. If the gat does value addition to only a part of the produce of the farmers it will get
# ================
# ================
#  marks in proportion to the extent to which such value addition has been done.E.g. If the total production of the Gat is 100 quintals of which value addition has been done for 50
# ================
# ================
#  quintals, then the Gat will get 7.5 marks in this category.
#
# The photos and videos of all activities / work done by the Gat in this regard must be posted on the Gat's WhatsApp group. These photos and videos will be checked during the judging process.
#
# 3. Arrangements for Storage: 5 marksOften prices crash during the harvest period but go up once the harvest period is over. Proper arran
# ================
# ================
# gements for storage are critical to being able to achieve a proper price for the product. Storage with warehouse receipts can also enable farmers to get a cash flow and hold onto their produce till they get a proper price. A lot of storagearrangements are available on rent but an individual farmer is not able to spend the money on transp
# ================
# ================
# ort or on rent. Making arrangements for storage is therefore a critical part of the functioning of a gat. For this purpose, a gat must show documentation that establishes that the gat has gathered information about available storage and made arrangements for such storage which includes information about the cost of such storage, when it would be made available and the volume of such availability. The decision whether to use such storage would be that of the individual farmer. 5 marks will be giv
# ================
# ================
# en to a gat which makes arrangements for storage. Please note these marks will be given whether or not farmers actually use these storage arrangements.Since Onion, Tomato, Cauliflower, Cabbage and other vegetables are highly perishable, storage arrang
# ================
# ================
# ements are not viable for these crops and hence gats cultivating these crops will get full 5 marks under this Section.
#
# If storage is arranged at home, it should be recorded on the Paani Foundation app and the photos / videos should be posted on the WhatsApp group. These photos and videos will be checked during the judging process.V. GAT AS AN INSTITUTION: 80 Marks
#
# 1. Accounts of the Gat: 2.5 Marks
#
# A proper functioning gat is a
# ================
# ================
#  business unit that must maintain proper books of account. The joint purchase of inputs, the contributions of Members for these inputs, the realisations from sale of the crop etc. must all be reflected in the books of account which must be entered on the Paani Foundation App.Hence, if proper books of account of the gat are not maintained, then it is not possible to calculat
# ================
# ================
# e marks for several other sections in the competition eg. Joint Purchase of inputs: 10 Marks, Joint Efforts for Sale: 10 Marks, Value Addition: 15 Marks etc.
#
# If proper books of account of the gat are not maintained then there will be no option but to give zero marks for each of these sections.
#
# 2. Bank Account of the Gat : 2.5 MarksThe gat must have a bank account for which it will get 2.5 Marks.
#
# 3. Farmers Books of Account Marks
# ================
# ================
# : 10 MarksEvery individual farmer who is part of the gat is running a business and hence must keep books of ac
# ================
# ================
# count. 10 Marks will be given if every farmer in the gat maintains books of account via the Paani Foundation App. If only some members of the gat maintain books of account then the gat will get marks in proportion to the number of farmers maintaining books of account. Eg. In a gat with 20 members only 10 members maintain books of account, then the gat will get 5 marks.A farmer must make ALL the entries - from pre-sowing operations to transport for sale in the books o
# ================
# ================
# f account to get marks under this Section.
#
# If all the members of the gat do not make all the entries on the Paani Foundation App as required by this Section, it is not possible to calculate marks for several other sections in the competition eg. Joint Purchase of inputs: 10 Marks, Joint Efforts for Sale: 10 Marks, Value Addition: 15 Marks, Profit of the gat : 40 Marks etc.If all the members of the gat do not make all the entries on the Paani Foundation App as required by
# ================
# ================
#  this section, then there will be no option but to give zero marks for each of these sections.
#
# 4) Cost-Revenue for Previous Kharif Crop - 5 marksWriting the cost, revenue and yield for the previous kharif season will help farmers know whether or
# ================
# ================
#  not this year’s farming is a step in the right direction. Hence marks will be given for entering this data for the previous kharif crop in accordance with the table below.
#
# Percentage of Members of the gat who enter cost, revenue yield data for the previous Kharif Crop
#
# Marks
#
# 50% +
#
# 5
#
# 40% + to 50%
#
# 4
#
# 30% + to 40%
#
# 3
#
# 20% + to 30%
#
# 2
#
# 10% to 20%
#
# 1Less than 10%
#
# 0
#
# Receipts / documents of Accounts are not expected in this regard.
#
# 5. Inter-gat Co
# ================
# ================
# operation: 5 MarksThe present gats are a stepping stone to large farmer producer organisations. The ultimate goal is a
# ================
# ================
# n FPO - whether under the Companies Act or the Cooperative Societies Act which has the economies of scale necessary to solve all the problems of farmers. This requires farmers with at least 1,000 acres of land coming together. This cannot be achieved overnight. As a first step the gats competing in this competition should cooperate with other gats in the matter of purchase of inputs, sale of crop, marketing arrangements or any other matter that forms a part of this spardha.
# ================
# ================
# The competing gats must enter on the App the various activities for which they have entered into int
# ================
# ================
# er-gat cooperation along with supporting documents. For each such activity, 2.5 marks will be allotted. A total of 5 Marks will be allotted for inter-gat cooperation.
#
# 6. Contribution to Community Work: 5 MarksThe gat is a part of the village and both benefits from and contributes to the overall well-being of
# ================
# ================
#  the village. Gats can contribute to the village through shramdan for tree plantation, creation and maintenance of grasslands or any other activity that is a part of the Samruddha Gaav Spardha. The gat must enter on the App which of such activities the gat has participated in. Participation in 2 or more activities of the village will be given 5 marks. The Gat will receive 2.5 marks for each such activity. The group will get a maximum of 5 marks under this section.
# ================
# ================
# The photos and videos of all activities / work done by the Gat in this regard must be posted on the
# ================
# ================
# Gat's WhatsApp group. These photos and videos will be checked during the judging process.
#
# 7. Profitability of the Gat (40 marks)A gat is first and foremost an economic entity. Its success or failure and indeed its possibility of
# ================
# ================
#  survival or growth will depend on its performance as an economic entity. The Profit and Loss statement of the gat will reveal its performance as an economic entity. Marks under this Section will be given under the headings of profit per acre and percentage of profits. The profits will be calculated in the following manner.The Planning Department, Government of Maharashtra through the Directorate of Statistics and Economi
# ================
# ================
# cs in June 2021 published its final report on the cost and revenue of various crops. Accordingly, a table giving the cost of production per acre of each crop is given in the appendix at the end of this document.
#
# This report is available via this link: https://mahades.maharashtra.gov.in/surveyReports.do?repCatId=CFAUsing the costs given in the table above as a benchmark, the Paani Foundation App will calculate the
# ================
# ================
#  cost of cultivation incurred by the gat in the following manner:
#
# Total cost of cultivation of the gat = Average cost of cultivation per the table above in Rs/acre x Number of acres cultivated by the gatIn addition if the gat does value addition eg. converting maize into silage, then the costs pertaini
# ================
# ================
# ng to such conversion/value addition must be added. In further addition, the gat incurs costs pertaining to sale of the produce eg. cost of transport of handling, weighing and commission paid to traders. In case of safe storage of agricultural produce without sale till 31st January 2023, these expenses will be charged according to the rates available in the taluka market.Hence: Total cost of the gat = Total Cost of cultivation + Cost of Value addition (if any) + Costs i
# ================
# ================
# ncurred for sale.
#
# Now let’s see how the revenue of the gat is calculated.
#
# Total revenue of the gat = Sum of revenue from sale of the main crop by each farmer + Sum of revenue from sale of the intercrop by each farmer + Sum of revenue from sale of the by-product (eg. soybean straw) by each farmer + Sum of revenue from sale of the value added product (if any) by each farmerOn this basis, the profit percentage and also profit/acre for each gat will be calculated.
#
# Profit o
# ================
# ================
# f the gat = Total revenue of the gat – Total Cost of cultivation of the gat
#
# Profit percentage = Profit of the gat/Total Cost of the Gat x 100
#
# Profit/Acre = Profit of the Gat/Number of Acres under cultivation by the gat
#
# 20 marks are allocated for Profit/acre and 20 Marks forProfit Percentage.
#
# A. Profit per acre (Rs)
#
# Profit per acre (Rs)Marks
#
# 50,000 +
#
# 20
#
# 40,000 + to 50,000
#
# 16
#
# 30,000 + to 40,000
#
# 12
#
# 20,000+ to 30,000
#
# 8
#
# 10,000+ t
# ================
# ================
# o 20,000
#
# 4
#
# 10,000 or less
#
# 0
#
# B. Profit percentage
#
# Profit percentage
#
# Marks
#
# 100%+
#
# 20
#
# 60%+ to 100%
#
# 15
#
# 40%+ to 60%
#
# 12
#
# 25%+ to 40%
#
# 8
#
# 10%+ to ते 25%
#
# 5
#
# 10% or less
#
# 0
#
# 8. Team Work, Leadership and Vision: 10 MarksA gat is a collection of human beings each with their own background, thoughts and points of view. O
# ================
# ================
# ne of the biggest challenges of the gat is good team work. How does a gat handle differences? What is its vision? What is the quality of leadership?. All these factors contribute greatly to the success or failure of the gat. All gats that stand a chance of winning a prize in the competition on the basis of all the other heads above will be judged on this criteria by Paani Foundation judges appointed for this purpose. 10 Marks have been allocated under this section.
# ================
# ================
# APPENDIX
#
# Name of Crop
#
# Production Cost/Acre in Rs Based on Govt. of Maharashtra Data
#
# Bajra
#
# 14317.
# ================
# ================
# 39
#
# Maize
#
# 24302.07
#
# Kh. Paddy
#
# 23260.31
#
# Kh. Jowar
#
# 18182.56
#
# Ragi
#
# 11099.19
#
# Tur
#
# 22604.45
#
# Moong
#
# 17638.09
#
# Udid
#
# 15482.25
#
# Groundnut
#
# 32588.52
#
# Soybean
#
# 20718
#
# Cotton
#
# 26476.78
#
# Coriander Seed
#
# 17236.61
#
# Ajwain
#
# 27852
#
# Beans
#
# Cabbage
#
# Cauliflower
#
# Capsicum
#
# Brinjal
#
# Okra
#
# Kh. Onion
#
# Ivy gourd
#
# Potato
#
# Sweet Potato
#
# Pumpkin
#
# Tomato
#
# Bitter gourd
#
# Bottle gourd
#
# Pointed gourd
#
# Ridge gourdSponge gourd
#
# Peas
#
# Green Chili
#
# Coriander
#
# Fenugreek
#
# Leafy Veg. (Spinach)
#
# Other Veg. (Cluster bea
# ================
# ================
# n)LIST OF SOPs
#
# A. पूवमशागत १. उताराला आडवी नांगरणी करणे. २. उहात नांगरणी करणे. ३. पूण कु जलेले शेण
# ================
# ================
# खत मातीआड करणे.
#
# 70910.82
#
# 63710.1
#
# 60283.5
#
# 96244.67
#
# 75618.92
#
# 50973.45
#
# 38976.16
#
# 68330.43
#
# 89096.67
#
# 47356.71
#
# 75348.73
#
# 82125.69
#
# 74200.78
#
# 46990.83
#
# 45223.84
#
# 63444.83
#
# 75829.71
#
# 38214.89
#
# 70140.69
#
# 23554.54
#
# 25019.89
#
# 28404.51
#
# 29119.35
#
# B. बयाणे नवड १. उपलध वाणांचा अयास करणे. २. बयायाची उगवण मता तपासणी करणे. ३. बीजया करणे.C. पेरणी १. BBF पधतीने पेरणी करणे. २. सर वरंबा / गाद वायावर टोकन पधतीने पेरणी करणे. ३. पकांया
# ================
# ================
#  दोन ओळी व रोपांमये योय अंतर ठे वणे.
#
# D. खतयवथापन १. माती परण करणे. २. माती परणानुसार खतांचा योय वापर करणे. ३. जीवामृत आण वाय खतांचा योय वापर करणे.
#
# E. तणनयंण १. सायकल कोळपे, हात कोळपे, खुरपणी वारे तणनयंण करणे.
#
# F. पाणी यवथापन १. ठबक संचन / तुषार संचन वारे पाणी देणे. २. आछादन करणे.G. कडयवथापन १. चकट सापळे वापरणे. २. काश सापळे वापरणे. ३. कामगंध सापळे वापरणे. ४. पीथांबे तयार
# ================
# ================
# करणे. ५. जैवक कटकनाशकांचा वापर करणे. ६. जैवक बुरशीनाशकांचा वापर करणे. ७. सापळा पके घेणे.
# ================
